# %% [raw]
# ---
# title: "Yas preprocessing pipeline"
#
# date: today
#
# format:
#   html:
#     toc: true
#     #toc-depth: 3
#     toc-expand: true
#     smooth-scroll: true
#     # code-fold: true
#     # code-tools: toggle
#     number-sections: true
#     comments:
#       hypothesis:
#         theme: clean
#         openSidebar: false
#
# execute:
#   output: false  # hide output
# ---

# %% [markdown]
# # Libraries

# %%
import os
import mne
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pandas as pd

from scipy import signal
from scipy.io import wavfile

# from pybv import write_brainvision
from pyprep.prep_pipeline import PrepPipeline
from mne_icalabel import label_components

# set working directory
work_dir = '/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/'
# pc
# work_dir = '/Users/hanch/OneDrive - University of Toronto/Projects/Yas accent/'

# %% [markdown]
# # Trigger lag fix

# %% [markdown]
# ## parameters

# %%
# directory
input_dir = work_dir + 'data_raw/'
output_dir = work_dir + 'data_preprocessed/1_trigger_lag_fixed/'
# create a folder if the folder doesn't exist
os.makedirs(output_dir, exist_ok=True)

# create a dictionary for blocks and markers
block_dict = {
    'ChEn':1000, # standard: chinese; deviant: english
    'EnCh':2000, # standard: english; deviant: chinese
    'InEn':3000, # standard: indian; deviant: english
    'EnIn':4000, # standard: english, deviant: indian
}


# exclude participants with missing data
exclude_ppts = [
    '140', # no data
    '197', # no data
    
    '135', # incomplete data
    '179', # incomplete data
    '182', # incomplete data

    '141', # wrong experiment was run

    '261', # no StimTrak recording

    '271', # no stimtrak
    '272', # no stimtrak

    '115', # unknown
]

# trigger searching window (actual trigger time based on audio - trigger time in the data)
t_left = -0.01
t_right = 0.05

# %%
#######################################################
#### create a dictionary for trigger codes and descriptions ####
df = pd.read_csv("mapping.txt", delimiter='\t')
mapping = dict(zip(df['code'], df['description']))
#######################################################

#### create a trigger dictionary for each stim's standard version and deviant version ####

# intialize a dictionary for triggers
trigger_dict = {}

# read in trigger_codes file
with open('trigger_codes.txt','r') as tf:
    for line in tf:
        # read in the current line
        line = line.replace('\n','')
        # separate fileNames and triggerMarker
        label, marker = line.split('\t')
        # convert trigger markers to integer
        marker = int(marker)
        # create label for stims used as standards
        trigger_dict[marker] = label + '-s'
        # add 100 for deviant marker
        marker_deviant = marker + 100
        # create label for stims used as deviants
        trigger_dict[marker_deviant] = label + '-d'



#### trigger correction for each file ####

# initialize a dictionary to save bad stims
all_bad_stim_dict = {}

# read in eeg data files
all_files = os.listdir(input_dir)

#### for each file, create an all_block dictionary to store each block and the indices of trials of that block  ####
for file in all_files:
    if file.endswith(".vhdr") and (file.split('.')[0]+ '_corr.fif' not in os.listdir(output_dir)):

        # exclude bad data
        if (file.split('.')[0].split('_')[1] in exclude_ppts):
            continue
            
        # read in vhdr files
        raw = mne.io.read_raw_brainvision(input_dir + file, preload = True)

        # extract sampling rate
        eeg_sfreq = raw.info['sfreq']
        
        # If the aux channel is not named 'StimTrak', change the channel name to 'StimTrak'
        if raw.info['ch_names'][31] != 'StimTrak':
            # change the channel name
            raw.rename_channels({raw.info['ch_names'][31]: 'StimTrak'})
            # specify the audio channel
            raw.set_channel_types({'StimTrak':'misc'})

        ##########################################################################################
        #### get trigger code, audio data, create a trigger dictionary for each stim's standard version and deviant version ####

        # initialize dictionaries
        audio = {}
        lengths = {}
        
        # del trigger_dict[99999]
        for marker,label in trigger_dict.items():
            # extract file name
            file_name = label[:7]
            # if not already in audio dictionary, get the info of the audio file
            if file_name not in audio:
                # get sample rate and data of the audio file
                sampleRate, data = wavfile.read(work_dir + 'yas_exp/stimuli/{}.wav'.format(file_name))
                # calculate sound file length
                lengths[file_name] = len(data)/sampleRate
                # reduce the sampling rate of the audio file by the factor of int(sampleRate/eeg_freq)
                data_downsampled = signal.decimate(data,int(sampleRate/eeg_sfreq), ftype='fir')
                # add info the audio dictionary
                audio[file_name] = data_downsampled

        #### making events ####
        # for each stimulus, mark the block info
        events_from_annot, event_dict = mne.events_from_annotations(raw, verbose='WARNING')
        # remove useless markers (New Segment: 99999, pause: 222, and continue: 223)
        events_from_annot = events_from_annot[events_from_annot[:, 2] < 200]
                
        # initialize the train for each standards+deviant sequence
        train = np.array([]).astype(int)
        
        all_block = {}
        isStandard = True # whether the standard in a train has been noted
            
        # loop over each trigger
        for i in range(events_from_annot.shape[0]):
                
            # add the current token to the train
            train = np.append(train,i)

            # trigger code
            trigger_marker = events_from_annot[i,2]
            
            # if the trigger code is smaller than 100 and the standard note is true
            if (trigger_marker<100) & isStandard:
                # save the standard stim category
                block = trigger_dict[trigger_marker][:2]
                # toggle standard note
                standard = False

            # if the trigger value is over 100
            elif trigger_marker>100:
                # append the deviant stim category 
                block = block + trigger_dict[trigger_marker][:2]

                # if the block is not present in all block
                if block not in all_block:
                    # add the new block and the token idx
                    all_block[block] = train[2:] # [2:] to exclude the first 2 standards
                else:
                    # add the token idx to the existing block
                    all_block[block] = np.concatenate([ all_block[block], train[2:] ], axis=None)

                # reset train
                train = np.array([]).astype(int)

                # toggle standard note
                isStandard = True
        
        # loop over each block and its trigger index
        for k,v in all_block.items(): 
            # recode the trigger value to reflect block and stim category
            events_from_annot[tuple(v),2] += block_dict[k]

        # exclude the first 2 standards
        events_from_annot = events_from_annot[events_from_annot[:,2]>1000]
        ##########################################################################################
        
        ########################################################
        #### calculate cross correction to detect the delay ####
        
        # initialize delay list
        delays = np.array([])
        # initialize bad stim list
        bad_stim = []
        corr_results = []
        
        # loop over each event
        for i in range(events_from_annot.shape[0]):

            # get current event info [time, duration, annotation]
            event = events_from_annot[i]
            # get the onset latency (s) of the event
            time = event[0]/eeg_sfreq
            # get the file name of the event
            name = trigger_dict[event[2]%100].split('-')[0]
            # get the data from the sound channel
            audio_eeg = raw.get_data(
                picks = ['StimTrak'],
                tmin = time + t_left,
                tmax = time + lengths[name] + t_right,
            )[0]
            # actual stimulus
            audio_stim = audio[name]
            
            # Z-score normalization (subtract mean, divide by std)
            audio_eeg = (audio_eeg - np.mean(audio_eeg)) / np.std(audio_eeg)
            audio_stim = (audio_stim - np.mean(audio_stim)) / np.std(audio_stim)

            # cross-correlation
            corr = signal.correlate(audio_eeg, audio_stim, mode='full')
            # Normalize cross-correlation
            corr = corr / (np.linalg.norm(audio_eeg) * np.linalg.norm(audio_stim))
            # Find peak correlation value
            max_corr = np.max(corr)    
            
            # if the maximum correction (sum of products) is less than a threshold (empirical, but 0.5 is good for most cases)
            if max_corr < 0.5:
                # mark the stim bad
                bad_stim.append(i)
            
            # append the maximum correlation
            corr_results.append(max_corr)
            
            # the lags for cross-correlation
            lags = signal.correlation_lags(
                audio_eeg.size,
                audio_stim.size,
                mode="full")
            # get the lag of the maximum cross-correlation
            lag = lags[np.argmax(corr)] + t_left*eeg_sfreq
            
            # save the lag for non-starting events
            delays = np.append(delays, lag)
        ########################################################

        ##################################################################################################
        #### plot the wave from the stim track and the eeg channel of the token with the minimum corr ####
        
        min_corr = np.argmin(corr_results)
        # get current event info [time, duration, annotation]
        event = events_from_annot[min_corr]
        # get the onset latency (s) of the event
        time = event[0]/eeg_sfreq
        # get the file name of the event
        name = trigger_dict[event[2]%100].split('-')[0]
        # get the data from the sound channel
        audio_eeg = raw.get_data(
            picks = ['StimTrak'],
            tmin = time + t_left,
            tmax = time + lengths[name] + t_right,
        )[0]
        # actual stimulus
        audio_stim = audio[name]
        # Z-score normalization (subtract mean, divide by std)
        audio_eeg = (audio_eeg - np.mean(audio_eeg)) / np.std(audio_eeg)
        audio_stim = (audio_stim - np.mean(audio_stim)) / np.std(audio_stim)
        # plot
        fig, ax = plt.subplots()
        ax.plot(audio_eeg, label = 'StimTrak', alpha = 0.6)
        ax.plot(audio_stim, label = 'wave', alpha = 0.6)
        ax.set_title(file)
        ax.legend()
        fig.savefig(output_dir + file.split('.')[0] + "_minCor.png", dpi=300, bbox_inches='tight')
        ##################################################################################################

                
        ####################################################
        #### correct for trigger lag and save log files ####

        # add number of bad stim info
        all_bad_stim_dict[file] = len(bad_stim)

        # remove items associated with bad stims from the event list
        events_from_annot = np.delete(events_from_annot, bad_stim, 0)
        
        # remove items associated with bad stims from the delay list
        delays = np.delete(delays, bad_stim, 0)

        # add delay back to the onset latency of each event
        events_from_annot[:,0] = events_from_annot[:,0] + delays

        # # convert individual event marker to conditions
        # events_from_annot[:,2] = events_from_annot[:,2] - events_from_annot[:,2]%100

        # create annotations
        annot_from_events = mne.annotations_from_events(
            events = events_from_annot,
            event_desc = mapping,
            sfreq = raw.info['sfreq']
        )

        # set annotations
        raw.set_annotations(annot_from_events)
        
        # drop the audio channel in data
        raw.drop_channels(['StimTrak'])
        
        # save as a file-into-file data
        raw.save(output_dir + file.split('.')[0]+ '_corr.fif')
        
        # save lag data
        np.savetxt(output_dir + file.replace('.vhdr', '_delays.txt'), delays, fmt='%i')
        ####################################################
        

# save the number of bad stims of all participant
with open(output_dir + 'bad_stim.txt', 'a') as f:
    for key, value in all_bad_stim_dict.items():
        if value > 0:
            f.write(key + '\t' + str(value) + '\n')
# Out:
# Extracting parameters from /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_raw/Yas_261.vhdr...
# Setting channel info structure...
# Reading 0 ... 1747174  =      0.000 ...  3494.348 secs...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 245
#     239 events_from_annot[:,0] = events_from_annot[:,0] + delays
#     241 # # convert individual event marker to conditions
#     242 # events_from_annot[:,2] = events_from_annot[:,2] - events_from_annot[:,2]%100
#     243
#     244 # create annotations
# --> 245 annot_from_events = mne.annotations_from_events(
#     246     events = events_from_annot,
#     247     event_desc = mapping,
#     248     sfreq = raw.info['sfreq']
#     249 )
#     251 # set annotations
#     252 raw.set_annotations(annot_from_events)
#
# File <decorator-gen-70>:12, in annotations_from_events(events, sfreq, event_desc, first_samp, orig_time, verbose)
#
# File /opt/anaconda3/lib/python3.12/site-packages/mne/annotations.py:1693, in annotations_from_events(events, sfreq, event_desc, first_samp, orig_time, verbose)
#    1643 """Convert an event array to an Annotations object.
#    1644
#    1645 Parameters
#    (...)
#    1690     event_desc = {v: k for k, v in event_id.items()}
#    1691 """
#    1692 event_desc = _check_event_description(event_desc, events)
# -> 1693 event_sel, event_desc_ = _select_events_based_on_id(events, event_desc)
#    1694 events_sel = events[event_sel]
#    1695 onsets = (events_sel[:, 0] - first_samp) / sfreq
#
# File /opt/anaconda3/lib/python3.12/site-packages/mne/annotations.py:1458, in _select_events_based_on_id(events, event_desc)
#    1455 event_sel = [ii for ii, e in enumerate(events) if e[2] in event_desc_]
#    1457 if len(event_sel) == 0:
# -> 1458     raise ValueError("Could not find any of the events you specified.")
#    1460 return event_sel, event_desc_
#
# ValueError: Could not find any of the events you specified.

# %% [markdown]
# # Bad channel correction
# - filtering
# - resampling
# - remove line noise
# - bad channel detection & repairing
# - add back reference channel TP9

# %% [markdown]
# ## parameters

# %%
# set directory
input_dir = work_dir + 'data_preprocessed/1_trigger_lag_fixed/'
output_dir = work_dir + 'data_preprocessed/2_bad_channel_corrected/'
# create a folder if the folder doesn't exist
os.makedirs(output_dir, exist_ok=True)

# filter cutoff frequencies (low/high)
f_low = 1
f_high = 100

# resampling frequency
f_res = 250

# line frequency
line_freq = 60

# preprocessing parameters
prep_params = {
    "ref_chs": 'eeg',
    "reref_chs": 'eeg', # average re-reference
    "line_freqs": np.arange(line_freq, f_res/2, line_freq),
}

# create a montage file for the pipeline
montage = mne.channels.make_standard_montage("standard_1020")

# interpolation method
# method=dict(eeg="spline")

exclude_ppts = [
    '187', # too many bad stims
    '200', # too many bad stims
    '259', # too many bad stims
    '273', # too many bad stims
]

# %%
#####################################################
#### Preprocessing (filtering, resampling, bad channel detection/interpoloation, re-reference) ####
#####################################################

# get all file namesin the folder
all_input = os.listdir(input_dir)
all_output = os.listdir(output_dir)


for file in all_input:
    if file.endswith("corr.fif") and (file.split('_')[1] not in exclude_ppts) and (file.split('.')[0]+ '_prep.fif' not in all_output):
        
        # read in file
        raw = mne.io.read_raw_fif(input_dir + file, preload=True)
        
        # set channel type
        raw.set_channel_types({'Fp1':'eog', 'Fp2':'eog'})

        # filter
        raw.filter(l_freq = f_low, h_freq = f_high)
        
        #### cut off the beginning and ending part ####
        
        # get the onset of the first and the last event ####
        events_from_annot, event_dict = mne.events_from_annotations(raw, verbose='WARNING')

        # define the beginning time (in seconds)
        crop_start = events_from_annot[0][0]/raw.info['sfreq'] - 10

        # define the ending time (in seconds)
        crop_end = events_from_annot[-1][0]/raw.info['sfreq'] + 10

        # crop the data
        raw.crop(
            tmin=max(crop_start, raw.times[0]), 
            tmax=min(crop_end, raw.times[-1])
        )
        
        # resample
        raw.resample(sfreq = f_res)

        # read in channel location info
        raw.set_montage(montage)
        
        ####  Use PrePipeline to preprocess ####
        '''
        1. detect and interpolate bad channels
        2. remove line noise
        3. re-reference
        '''
        
        # apply pyprep
        prep = PrepPipeline(raw, prep_params, montage, random_state=42)
        prep.fit()

        
        # export a txt file for the interpolated channel info
        with open(output_dir + 'bad_channel.txt', 'a+') as f:
            _ =f.write(
                file + ':\n' +
                "- Bad channels original: {}".format(prep.noisy_channels_original["bad_all"]) + '\n' +
                "- Bad channels after robust average reference: {}".format(prep.interpolated_channels) + '\n' +
                "- Bad channels after interpolation: {}".format(prep.still_noisy_channels) + '\n'
            )

        # save the pypred preprocessed data into the raw data structure
        raw = prep.raw

        # spline interpolating remaining bad channels if any
        raw.interpolate_bads()

        # add back the reference channel
        raw = mne.add_reference_channels(raw,'TP9')

        # add the channel loc info (for the newly added reference channel)
        raw.set_montage(montage)
        
        # save
        raw.save(output_dir + file.split('.')[0]+ '_prep.fif')
# Out:
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/1_trigger_lag_fixed/Yas_273_corr.fif...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:14: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/1_trigger_lag_fixed/Yas_273_corr.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Isotrak not found
#     Range : 0 ... 1788649 =      0.000 ...  3577.298 secs
# Ready.
# Reading 0 ... 1788649  =      0.000 ...  3577.298 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 1651 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:43: RuntimeWarning: Not setting positions of 2 eog channels found in montage:
# ['Fp1', 'Fp2']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw.set_montage(montage)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# Removed notch frequencies (Hz):
#      60.00 : 19604 windows
#     120.00 : 19604 windows
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/677 [00:00<?,       ?it/s]
# RANSAC done!
# 2025-07-19 00:50:41,763 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['P7'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['P7']}
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/677 [00:00<?,       ?it/s]
# RANSAC done!
# 2025-07-19 00:51:14,444 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['T8'], 'bad_by_correlation': ['T8'], 'bad_by_SNR': ['T8'], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['T8']}
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 93.4 mm
# Computing interpolation matrix from 28 sensor positions
# Interpolating 1 sensors
# 2025-07-19 00:51:14,770 - pyprep.reference - INFO - Iterations: 1
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/677 [00:00<?,       ?it/s]
# RANSAC done!
# 2025-07-19 00:51:45,399 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['T8'], 'bad_by_correlation': ['T8'], 'bad_by_SNR': ['T8'], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['T8']}
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 93.4 mm
# Computing interpolation matrix from 28 sensor positions
# Interpolating 1 sensors
# 2025-07-19 00:51:45,761 - pyprep.reference - INFO - Iterations: 2
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/677 [00:00<?,       ?it/s]
# RANSAC done!
# 2025-07-19 00:52:17,263 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['T8'], 'bad_by_correlation': ['T8'], 'bad_by_SNR': ['T8'], 'bad_by_dropout': [], 'bad_by_ransac': ['FT9'], 'bad_all': ['FT9', 'T8']}
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 93.4 mm
# Computing interpolation matrix from 27 sensor positions
# Interpolating 2 sensors
# 2025-07-19 00:52:17,660 - pyprep.reference - INFO - Iterations: 3
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/677 [00:00<?,       ?it/s]
# RANSAC done!
# 2025-07-19 00:52:48,836 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': ['T8'], 'bad_by_correlation': ['T8'], 'bad_by_SNR': ['T8'], 'bad_by_dropout': [], 'bad_by_ransac': ['FT9'], 'bad_all': ['FT9', 'T8']}
# 2025-07-19 00:52:48,837 - pyprep.reference - INFO - Robust reference done
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 93.4 mm
# Computing interpolation matrix from 27 sensor positions
# Interpolating 2 sensors
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/677 [00:00<?,       ?it/s]
# RANSAC done!
# Found 1 uniquely bad channels:
#
# 0 by NaN: []
#
# 0 by flat: []
#
# 0 by deviation: []
#
# 1 by HF noise: ['T8']
#
# 1 by correlation: ['T8']
#
# 1 by SNR: ['T8']
#
# 0 by dropout: []
#
# 0 by RANSAC: []
#
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 93.4 mm
# Computing interpolation matrix from 28 sensor positions
# Interpolating 1 sensors
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/677 [00:00<?,       ?it/s]
# RANSAC done!
# Setting channel interpolation method to {'eeg': 'spline'}.
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_273_corr_prep.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:70: RuntimeWarning: No bad channels to interpolate. Doing nothing...
#   raw.interpolate_bads()
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:73: RuntimeWarning: Location for this channel is unknown or ambiguous; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
#   raw = mne.add_reference_channels(raw,'TP9')
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:76: RuntimeWarning: Not setting positions of 2 eog channels found in montage:
# ['Fp1', 'Fp2']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw.set_montage(montage)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:79: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_273_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_prep.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_273_corr_prep.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/1_trigger_lag_fixed/Yas_274_corr.fif...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:14: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/1_trigger_lag_fixed/Yas_274_corr.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Isotrak not found
#     Range : 0 ... 2007299 =      0.000 ...  4014.598 secs
# Ready.
# Reading 0 ... 2007299  =      0.000 ...  4014.598 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 1651 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.6s
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:43: RuntimeWarning: Not setting positions of 2 eog channels found in montage:
# ['Fp1', 'Fp2']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw.set_montage(montage)
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Removed notch frequencies (Hz):
#      60.00 : 22968 windows
#     120.00 : 22968 windows
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/793 [00:00<?,       ?it/s]
# RANSAC done!
# 2025-07-19 00:54:56,806 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FT9', 'T7'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': [], 'bad_all': ['FT9', 'T7']}
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/793 [00:00<?,       ?it/s]
# RANSAC done!
# 2025-07-19 00:55:37,998 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FT9'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T7'], 'bad_all': ['FT9', 'T7']}
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 93.4 mm
# Computing interpolation matrix from 27 sensor positions
# Interpolating 2 sensors
# 2025-07-19 00:55:38,747 - pyprep.reference - INFO - Iterations: 1
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/793 [00:00<?,       ?it/s]
# RANSAC done!
# 2025-07-19 00:56:17,947 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FT9', 'T7'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T7'], 'bad_all': ['FT9', 'T7']}
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 93.4 mm
# Computing interpolation matrix from 27 sensor positions
# Interpolating 2 sensors
# 2025-07-19 00:56:18,522 - pyprep.reference - INFO - Iterations: 2
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/793 [00:00<?,       ?it/s]
# RANSAC done!
# 2025-07-19 00:56:56,767 - pyprep.reference - INFO - Bad channels: {'bad_by_nan': [], 'bad_by_flat': [], 'bad_by_deviation': [], 'bad_by_hf_noise': [], 'bad_by_correlation': ['FT9', 'T7'], 'bad_by_SNR': [], 'bad_by_dropout': [], 'bad_by_ransac': ['T7'], 'bad_all': ['FT9', 'T7']}
# 2025-07-19 00:56:56,767 - pyprep.reference - INFO - Robust reference done
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 93.4 mm
# Computing interpolation matrix from 27 sensor positions
# Interpolating 2 sensors
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/793 [00:00<?,       ?it/s]
# RANSAC done!
# Found 2 uniquely bad channels:
#
# 0 by NaN: []
#
# 0 by flat: []
#
# 0 by deviation: []
#
# 0 by HF noise: []
#
# 2 by correlation: ['FT9', 'T7']
#
# 0 by SNR: []
#
# 0 by dropout: []
#
# 0 by RANSAC: []
#
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 93.4 mm
# Computing interpolation matrix from 27 sensor positions
# Interpolating 2 sensors
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Executing RANSAC
# This may take a while, so be patient...
#   0%|          |  : 0/793 [00:00<?,       ?it/s]
# RANSAC done!
# Setting channel interpolation method to {'eeg': 'spline'}.
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_274_corr_prep.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:70: RuntimeWarning: No bad channels to interpolate. Doing nothing...
#   raw.interpolate_bads()
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:73: RuntimeWarning: Location for this channel is unknown or ambiguous; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
#   raw = mne.add_reference_channels(raw,'TP9')
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:76: RuntimeWarning: Not setting positions of 2 eog channels found in montage:
# ['Fp1', 'Fp2']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw.set_montage(montage)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/1118127265.py:79: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_274_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_prep.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_274_corr_prep.fif
# [done]

# %% [markdown]
# # ICA bad trial correction

# %% [markdown]
# ## parameters

# %%
# directory
input_dir = work_dir + 'data_preprocessed/2_bad_channel_corrected/'
output_dir = work_dir + 'data_preprocessed/3_ica/'

# create a folder if the folder doesn't exist
os.makedirs(output_dir, exist_ok=True)

# run ica on epoched data or continuous data
ica_input_type = 'epoch'
# ica_input_type = 'continuous'

# up to which IC you want to consider
ic_upto = 15
# ic_upto = 99

# Epoch window: 
erp_t_start = -0.1; erp_t_end = 0.9

# %%
# get all file names in the folder
all_input = os.listdir(input_dir)
all_output = os.listdir(output_dir)


# for each file
for file in all_input:
    if file.endswith("prep.fif") and (file.split('.')[0]+ '_ica.fif' not in all_output): 
    
        # read in file
        raw = mne.io.read_raw_fif(input_dir + file, preload=True)
        
        # make a filtered file copy ICA. It works better on signals with 1 Hz high-pass filtered and 100 Hz low-pass filtered
        raw_filt = raw.copy().filter(l_freq = 1, h_freq = 100)
    
        # apply a common average referencing, to comply with the ICLabel requirements
        raw_filt.set_eeg_reference("average")

        # initialize ica components enough components to explain 0.999999 of the variance by default
        ica = mne.preprocessing.ICA(
            max_iter='auto', # n-1
            # use ‘extended infomax’ method for fitting the ICA, to comply with the ICLabel requirements
            method = 'infomax', 
            fit_params = dict(extended=True),
            random_state = 42,
        )

        # run ica on epochs or continuous
        if ica_input_type=="epoch":
            # get event info for segmentation
            events_from_annot, event_dict = mne.events_from_annotations(raw_filt, verbose='WARNING')
            # segmentation for ERP
            epochs = mne.Epochs(
                raw_filt,
                events = events_from_annot, event_id = event_dict,
                tmin = erp_t_start, tmax = erp_t_end,
                # apply baseline correction
                baseline = None,
                # remove epochs that meet the rejection criteria
                reject = None,
                preload = True,
            )
            # set ica_input
            ica_input = epochs
        elif ica_input_type=="continuous":
            ica_input = raw_filt
            
        #### get ica solution ####
        ica.fit(ica_input, picks = ['eeg'])
        # save ica solutions
        ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
        
        #### ICLabel ####
        ic_labels = label_components(ica_input, ica, method="iclabel")
        # save
        with open(output_dir + file.split('.')[0]+ '_icLabels.pickle', 'wb') as f:
            pickle.dump(ic_labels, f)

        #### auto select brain AND other ####
        labels = ic_labels["labels"]
        exclude_idx = [
            idx for idx, label in enumerate(labels) if idx<ic_upto and label not in ["brain", "other"]
        ]
        
        # ica.apply() changes the Raw object in-place
        ica.apply(raw, exclude=exclude_idx)

        # record the bad ICs in bad_ICs.txt
        with open(output_dir + '/bad_ICs.txt', 'a+') as f:
            _ = f.write(file + '\t' + str(exclude_idx) + '\n')
        
        # save data after ICA
        raw.save(output_dir + file.split('.')[0]+ '_ica.fif')

        # release memory
        del raw, raw_filt, ica_input
# Out:
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_143_corr_prep.fif...
#     Range : 1584 ... 847337 =      6.336 ...  3389.348 secs
# Ready.
# Reading 0 ... 845753  =      0.000 ...  3383.012 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_143_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Not setting metadata
# 1673 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1673 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 27 components
# Computing Extended Infomax ICA
# Fitting ICA took 137.1s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_143_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (27 components)
#     Zeroing out 4 ICA components
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_143_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_143_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_143_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_143_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_258_corr_prep.fif...
#     Range : 23135 ... 918784 =     92.540 ...  3675.136 secs
# Ready.
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_258_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Reading 0 ... 895649  =      0.000 ...  3582.596 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Not setting metadata
# 1714 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1714 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 23 components
# Computing Extended Infomax ICA
# Fitting ICA took 53.5s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_258_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (23 components)
#     Zeroing out 5 ICA components
#     Projecting back using 30 PCA components
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_258_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_258_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_258_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_258_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_150_corr_prep.fif...
#     Range : 16252 ... 917975 =     65.008 ...  3671.900 secs
# Ready.
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_150_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Reading 0 ... 901723  =      0.000 ...  3606.892 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Not setting metadata
# 1688 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1688 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 25 components
# Computing Extended Infomax ICA
# Fitting ICA took 47.4s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_150_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (25 components)
#     Zeroing out 8 ICA components
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_150_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_150_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_150_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_150_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_147_corr_prep.fif...
#     Range : 4448 ... 833991 =     17.792 ...  3335.964 secs
# Ready.
# Reading 0 ... 829543  =      0.000 ...  3318.172 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_147_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1630 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1630 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 25 components
# Computing Extended Infomax ICA
# Fitting ICA took 45.5s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_147_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (25 components)
#     Zeroing out 5 ICA components
#     Projecting back using 30 PCA components
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_147_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_147_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_147_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_147_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_169_corr_prep.fif...
#     Range : 5964 ... 860519 =     23.856 ...  3442.076 secs
# Ready.
# Reading 0 ... 854555  =      0.000 ...  3418.220 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_169_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1696 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1696 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 27 components
# Computing Extended Infomax ICA
# Fitting ICA took 356.5s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_169_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (27 components)
#     Zeroing out 7 ICA components
#     Projecting back using 30 PCA components
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_169_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_169_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_169_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_169_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_265_corr_prep.fif...
#     Range : 0 ... 838511 =      0.000 ...  3354.044 secs
# Ready.
# Reading 0 ... 838511  =      0.000 ...  3354.044 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_265_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Not setting metadata
# 1657 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1657 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 24 components
# Computing Extended Infomax ICA
# Fitting ICA took 50.3s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_265_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (24 components)
#     Zeroing out 8 ICA components
#     Projecting back using 30 PCA components
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_265_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_265_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_265_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_265_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_199_corr_prep.fif...
#     Range : 2359 ... 869776 =      9.436 ...  3479.104 secs
# Ready.
# Reading 0 ... 867417  =      0.000 ...  3469.668 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_199_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Not setting metadata
# 1688 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1688 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 28 components
# Computing Extended Infomax ICA
# Fitting ICA took 222.3s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_199_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (28 components)
#     Zeroing out 8 ICA components
#     Projecting back using 30 PCA components
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_199_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_199_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_199_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_199_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_228_corr_prep.fif...
#     Range : 2487 ... 965574 =      9.948 ...  3862.296 secs
# Ready.
# Reading 0 ... 963087  =      0.000 ...  3852.348 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_228_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1712 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1712 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 21 components
# Computing Extended Infomax ICA
# Fitting ICA took 41.8s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_228_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_228_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
#     Transforming to ICA space (21 components)
#     Zeroing out 4 ICA components
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_228_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_228_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_228_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_124_corr_prep.fif...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_124_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
#     Range : 0 ... 829601 =      0.000 ...  3318.404 secs
# Ready.
# Reading 0 ... 829601  =      0.000 ...  3318.404 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1639 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1639 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 27 components
# Computing Extended Infomax ICA
# Fitting ICA took 408.9s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_124_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (27 components)
#     Zeroing out 8 ICA components
#     Projecting back using 30 PCA components
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_124_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_124_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_124_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_124_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_133_corr_prep.fif...
#     Range : 2664 ... 935424 =     10.656 ...  3741.696 secs
# Ready.
# Reading 0 ... 932760  =      0.000 ...  3731.040 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_133_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1646 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1646 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 27 components
# Computing Extended Infomax ICA
# Fitting ICA took 207.1s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_133_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (27 components)
#     Zeroing out 4 ICA components
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_133_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_133_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_133_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_133_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_211_corr_prep.fif...
#     Range : 6000 ... 860712 =     24.000 ...  3442.848 secs
# Ready.
# Reading 0 ... 854712  =      0.000 ...  3418.848 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_211_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Not setting metadata
# 1713 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1713 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 23 components
# Computing Extended Infomax ICA
# Fitting ICA took 65.4s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_211_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (23 components)
#     Zeroing out 4 ICA components
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_211_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_211_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_211_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_211_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_206_corr_prep.fif...
#     Range : 0 ... 907845 =      0.000 ...  3631.380 secs
# Ready.
# Reading 0 ... 907845  =      0.000 ...  3631.380 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_206_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# Not setting metadata
# 1680 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1680 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 23 components
# Computing Extended Infomax ICA
# Fitting ICA took 53.3s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_206_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (23 components)
#     Zeroing out 5 ICA components
#     Projecting back using 30 PCA components
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_206_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_206_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_206_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_206_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_137_corr_prep.fif...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_137_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
#     Range : 3072 ... 868495 =     12.288 ...  3473.980 secs
# Ready.
# Reading 0 ... 865423  =      0.000 ...  3461.692 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Not setting metadata
# 1705 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1705 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 27 components
# Computing Extended Infomax ICA
# Fitting ICA took 319.4s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_137_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (27 components)
#     Zeroing out 3 ICA components
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_137_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_137_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_137_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_137_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_120_corr_prep.fif...
#     Range : 15267 ... 885848 =     61.068 ...  3543.392 secs
# Ready.
# Reading 0 ... 870581  =      0.000 ...  3482.324 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_120_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# ...
# Fitting ICA took 36.7s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_210_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (24 components)
#     Zeroing out 4 ICA components
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_210_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_210_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_210_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_210_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_132_corr_prep.fif...
#     Range : 10599 ... 860090 =     42.396 ...  3440.360 secs
# Ready.
# Reading 0 ... 849491  =      0.000 ...  3397.964 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_132_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1618 matching events found
# No baseline correction applied
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# 0 projection items activated
# Using data from preloaded Raw for 1618 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 28 components
# Computing Extended Infomax ICA
# Fitting ICA took 130.8s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_132_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (28 components)
#     Zeroing out 1 ICA component
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_132_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_132_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_132_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_132_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_125_corr_prep.fif...
#     Range : 13787 ... 862754 =     55.148 ...  3451.016 secs
# Ready.
# Reading 0 ... 848967  =      0.000 ...  3395.868 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_125_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1680 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1680 events and 251 original time points ...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.2s
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 20 components
# Computing Extended Infomax ICA
# Fitting ICA took 35.9s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_125_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 5 ICA components
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_125_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_125_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_125_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_125_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_198_corr_prep.fif...
#     Range : 0 ... 836361 =      0.000 ...  3345.444 secs
# Ready.
# Reading 0 ... 836361  =      0.000 ...  3345.444 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_198_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Not setting metadata
# 1641 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1641 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 27 components
# Computing Extended Infomax ICA
# Fitting ICA took 158.0s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_198_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (27 components)
#     Zeroing out 2 ICA components
#     Projecting back using 30 PCA components
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_198_corr_prep_ica.fif
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_198_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_198_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_198_corr_prep_ica.fif
# [done]
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_229_corr_prep.fif...
#     Range : 0 ... 948397 =      0.000 ...  3793.588 secs
# Ready.
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:11: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/2_bad_channel_corrected/Yas_229_corr_prep.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload=True)
# Reading 0 ... 948397  =      0.000 ...  3793.588 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 1e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 100.00 Hz
# - Upper transition bandwidth: 25.00 Hz (-6 dB cutoff frequency: 112.50 Hz)
# - Filter length: 825 samples (3.300 s)
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Not setting metadata
# 1710 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1710 events and 251 original time points ...
# 0 bad epochs dropped
# Fitting ICA to data using 30 channels (please be patient, this may take a while)
# Selecting by non-zero PCA components: 24 components
# Computing Extended Infomax ICA
# Fitting ICA took 38.5s.
# Writing ICA solution to /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_229_corr_prep_icaSolution.fif...
# Applying ICA to Raw instance
#     Transforming to ICA space (24 components)
#     Zeroing out 1 ICA component
#     Projecting back using 30 PCA components
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:54: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_229_corr_prep_icaSolution.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(output_dir + file.split('.')[0]+ '_icaSolution.fif', overwrite=True)
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_99184/2623835388.py:74: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_229_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(output_dir + file.split('.')[0]+ '_ica.fif')
# Writing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_229_corr_prep_ica.fif
# Closing /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_229_corr_prep_ica.fif
# [done]

# %% [markdown]
# # Epochs
# segmenting continuous EEG into epochs
# - re-reference
# - segmentation

# %% [markdown]
# ## parameters

# %%
# directory
input_dir = work_dir + 'data_preprocessed/3_ica/'
output_dir = work_dir + 'data_preprocessed/4_epochs/'
# create a folder if the folder doesn't exist
os.makedirs(output_dir, exist_ok=True)


# Epoch window: 
erp_t_start = -0.1; erp_t_end = 0.9

# criteria to reject epoch
reject_criteria = dict(eeg = 100e-6)       # 100 µV
# reject_criteria = dict(eeg = 150e-6)       # 150 µV
# reject_criteria = dict(eeg = 200e-6)       # 200 µV

# %%
# get file names
all_input = os.listdir(input_dir)
all_output = os.listdir(output_dir)


#### re-reference, and epoch ####
for file in all_input:
    
    if file.endswith("ica.fif") and (file.split('.')[0] + '_epo.fif' not in all_output):
        
        # read in data
        raw = mne.io.read_raw_fif(input_dir + file, preload = True)
        
        # average-mastoids re-reference
        raw.set_eeg_reference(ref_channels = ['TP9', 'TP10'])
        
        #### this is for source calculation ####
        # filter the data, optional
        # raw = raw.filter(l_freq=None, h_freq=30) 

        # sphere = mne.make_sphere_model('auto', 'auto', raw.info)
        # src = mne.setup_volume_source_space(sphere=sphere, exclude=30., pos=15.)
        # forward = mne.make_forward_solution(raw.info, trans=None, src=src, bem=sphere)
        # raw = raw.set_eeg_reference('REST', forward=forward)
        ########################################
        
        # get event info for segmentation
        events_from_annot, event_dict = mne.events_from_annotations(raw, verbose='WARNING')
        
        # segmentation for ERP
        epochs = mne.Epochs(
            raw,
            events = events_from_annot, event_id = event_dict,
            tmin = erp_t_start, tmax = erp_t_end,
            # apply baseline correction
            baseline = None,
            # remove epochs that meet the rejection criteria
            reject = reject_criteria,
            preload = True,
        )

        # remove 0 trial events, record info, and check if a subject is bad
        for k, v in event_dict.items():

            # good trial count
            trial_count = len(epochs[k])

            # remove 0 trial event
            if trial_count==0:
                del epochs.event_id[k]

            # good trial rate
            goodTrial_rate = round( trial_count/sum(events_from_annot[:,2]==v), 2 )
            
            # record epoch summary
            with open(output_dir + 'epoch_summary.txt', 'a+') as f:
                _ =f.write(file.split('_')[1] + '\t' + k + '\t' + str(trial_count) + '\t' + str(goodTrial_rate) + '\n')

        # save single participant file
        epochs.save(output_dir + file.split('.')[0] + '_epo.fif',
                   overwrite=True)
# Out:
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_191_corr_prep_ica.fif...
#     Range : 4661 ... 845786 =     18.644 ...  3383.144 secs
# Ready.
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_9424/962732743.py:15: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_191_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload = True)
# Reading 0 ... 841125  =      0.000 ...  3364.500 secs...
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1648 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1648 events and 251 original time points ...
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'Pz', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'O1', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['F7', 'FC1', 'T7', 'Pz', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'O1', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'O1', 'T8']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Fz', 'T7', 'O2', 'T8', 'F4']
#     Rejecting  epoch based on EEG : ['T7', 'Cz', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'T7', 'Pz', 'O1', 'O2', 'P8', 'Cz', 'T8', 'FC2']
#     Rejecting  epoch based on EEG : ['T7', 'Pz', 'CP2', 'Cz']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['FC1', 'T7', 'P7', 'O1', 'Cz', 'T8', 'F4']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['O1', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'O1']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['O2', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'T8', 'FC2']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T7', 'O1', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'O1', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'P3', 'P7', 'O1', 'O2', 'T8']
#     Rejecting  epoch based on EEG : ['O2', 'T8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T7', 'Cz']
#     Rejecting  epoch based on EEG : ['P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'Oz', 'O2', 'P8', 'FC2']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'O1', 'F8']
#     Rejecting  epoch based on EEG : ['T7', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['T7', 'Pz', 'P3']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['T7', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'Pz', 'O2', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'T7', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'Cz', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'T7', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Pz', 'O2', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'O1', 'Oz', 'O2', 'P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O2', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC5', 'FC1', 'T7', 'CP5', 'O1', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'C3', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'T7', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'T7', 'O2', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'Oz', 'O2', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Pz', 'O2']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC1', 'C3', 'T7', 'CP5', 'O1', 'O2', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'O1', 'O2', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2', 'P8', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['F7', 'C4', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'O1', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'P7', 'O1', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'Pz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'CP1', 'Pz', 'P7', 'O1', 'CP2', 'Cz', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'Pz', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FC1', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'FC2']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Pz', 'O1', 'O2', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'T7', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'P8', 'Cz', 'F4']
#     Rejecting  epoch based on EEG : ['F7', 'Cz', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'O1', 'O2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'Oz', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['C3']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FC1', 'C3', 'CP1', 'Pz', 'O1', 'Oz', 'O2', 'P4', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['Pz', 'Cz']
#     Rejecting  epoch based on EEG : ['O1', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'O1', 'Oz', 'O2', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz']
#     Rejecting  epoch based on EEG : ['FC1', 'O1', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'Pz', 'O1', 'Oz', 'O2', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'O1', 'O2', 'P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Pz', 'Oz']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'O1', 'Oz', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'T7', 'CP5', 'P7', 'O1', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'Oz', 'O2', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['O1', 'P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'Cz']
#     Rejecting  epoch based on EEG : ['P3', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O2']
#     Rejecting  epoch based on EEG : ['CP1', 'O1', 'O2', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'O2', 'P4', 'P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'O1', 'FC2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'CP1', 'O1', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Cz']
#     Rejecting  epoch based on EEG : ['Pz', 'O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Pz', 'O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Pz', 'O1']
#     Rejecting  epoch based on EEG : ['Pz', 'O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'Cz', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'T7', 'O1']
#     Rejecting  epoch based on EEG : ['O1', 'Cz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2', 'Cz']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'P3', 'O1', 'CP2', 'Cz']
#     Rejecting  epoch based on EEG : ['Pz', 'O1']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'O1', 'CP2', 'Cz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Cz']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8', 'FC2']
#     Rejecting  epoch based on EEG : ['Pz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'P3', 'O2', 'P4', 'CP2', 'Cz', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['F7', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'O1', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'Pz', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Pz', 'Oz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'Pz', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'O2', 'P8', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'O1', 'Oz', 'O2', 'P8', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['T7', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['P4', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2']
#     Rejecting  epoch based on EEG : ['FC6', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Pz', 'Cz', 'C4', 'FC6']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EEG : ['Pz', 'FC6']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EEG : ['C4', 'FC6']
#     Rejecting  epoch based on EEG : ['C4', 'FC6', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Oz', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Pz', 'P3', 'P7']
#     Rejecting  epoch based on EEG : ['Pz', 'P3']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Pz', 'Cz']
#     Rejecting  epoch based on EEG : ['O1', 'P8']
#     Rejecting  epoch based on EEG : ['Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1', 'Cz']
#     Rejecting  epoch based on EEG : ['Pz', 'Cz']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'Cz']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'T7', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'F4']
#     Rejecting  epoch based on EEG : ['FC1', 'Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'T7', 'P3', 'O2', 'P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'Cz', 'F4']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'O1', 'Oz', 'O2', 'T8', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'CP1', 'Pz', 'P3', 'O1', 'Oz', 'O2', 'P4', 'P8', 'Cz', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'C3', 'CP5', 'Pz', 'P3', 'P7', 'O1', 'CP6', 'CP2', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'CP2', 'Cz']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz']
#     Rejecting  epoch based on EEG : ['O1', 'P8']
#     Rejecting  epoch based on EEG : ['Pz', 'P4', 'CP2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'F4']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Pz', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['CP1', 'P3', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Pz', 'O1']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'Oz', 'O2', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'CP2', 'Cz', 'C4', 'FC6', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'Oz', 'Cz']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['CP1', 'O2', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'T7', 'O1', 'Oz', 'O2', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['P8', 'F4']
#     Rejecting  epoch based on EEG : ['Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FC1', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['FC1', 'O1', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'T7', 'CP5', 'Oz', 'O2', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'O2', 'P8', 'Cz', 'F4']
#     Rejecting  epoch based on EEG : ['F7', 'O2', 'T8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['FC1', 'CP5', 'O2', 'Cz', 'T8']
#     Rejecting  epoch based on EEG : ['FC1', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O2', 'Cz']
#     Rejecting  epoch based on EEG : ['O2', 'Cz', 'T8']
#     Rejecting  epoch based on EEG : ['O2', 'Cz', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'O2', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Fz', 'O2', 'T8', 'F4']
#     Rejecting  epoch based on EEG : ['O2', 'P8', 'T8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O2', 'Cz', 'C4', 'FC6', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'T7', 'O1', 'Oz', 'O2', 'P8', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'Pz', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FC2']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Fz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FC1', 'O2', 'P8', 'Cz', 'FT10', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Fz', 'T7', 'P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'FC2']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'CP1', 'Pz', 'P3', 'O2', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Cz', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'P8']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['FC1', 'O2', 'T8', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'Pz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['Pz', 'P3', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Pz', 'T8']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O2', 'P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2', 'T8']
#     Rejecting  epoch based on EEG : ['O2', 'T8']
#     Rejecting  epoch based on EEG : ['Pz', 'Cz']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['FC1', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Oz', 'T8']
#     Rejecting  epoch based on EEG : ['O2', 'P8', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O2', 'Cz', 'T8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'O2', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'Pz', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2', 'Cz']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'CP1', 'Pz', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'C4', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['F7', 'Oz', 'O2', 'P8', 'T8', 'F4']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'Pz', 'O1', 'O2', 'Cz', 'T8', 'FT10', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2', 'T8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Pz', 'T8']
#     Rejecting  epoch based on EEG : ['T8', 'FC2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'Oz', 'P4', 'CP2', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Cz', 'T8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P3', 'P7', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P3']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Pz', 'T8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'Pz', 'P3', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'T7', 'O1', 'Oz', 'O2', 'P8', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'CP1', 'P3', 'P7', 'O1', 'Oz', 'CP2', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['F7', 'CP1', 'Pz', 'P3', 'O1', 'Cz', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'C3', 'T7', 'CP5', 'O1', 'Oz', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'Pz', 'O1', 'Oz', 'P4', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['P3', 'P7', 'O1', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['F7', 'C3', 'CP1', 'Pz', 'O1', 'Oz', 'P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FC1', 'T7', 'Pz', 'P3']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'O1', 'Oz', 'O2', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'O1', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['F3', 'FC1', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'T8', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1', 'P8']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'Oz', 'O2', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'CP1', 'Pz', 'P3', 'O1', 'CP2', 'Cz']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['F7', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC5', 'FC1', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'Oz', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['F3', 'T7', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'CP1', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz']
#     Rejecting  epoch based on EEG : ['FC1', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P8', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'P8']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'P4', 'P8', 'T8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'O1', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'C3', 'T7', 'CP5', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'O1', 'Oz', 'O2', 'P8', 'T8', 'FT10', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC1', 'C3', 'T7', 'CP5', 'O1', 'P4', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'T7', 'Pz', 'O1', 'Oz', 'T8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'T7', 'CP5', 'FC6']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P3']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'P8', 'Cz', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F4']
#     Rejecting  epoch based on EEG : ['FC1', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'T8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['FC1', 'O1']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'T7', 'P7', 'O1', 'Oz', 'O2', 'P8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Pz', 'O2', 'P8', 'T8']
#     Rejecting  epoch based on EEG : ['F3', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['F7', 'Pz', 'O1', 'O2', 'P4', 'CP2']
#     Rejecting  epoch based on EEG : ['O1', 'T8']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'Cz']
#     Rejecting  epoch based on EEG : ['O2', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FC1', 'C3', 'O1', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['C3', 'CP1', 'Pz', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'O1', 'Oz', 'O2', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EEG : ['Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'O2', 'P4', 'P8', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'O2', 'FC2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['FC1', 'P3']
#     Rejecting  epoch based on EEG : ['FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2', 'C4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'O2', 'P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'Cz']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'T7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['T7', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['FC1', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['C3', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['F7', 'C3', 'O2', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'C3', 'O2']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz']
#     Rejecting  epoch based on EEG : ['C3']
#     Rejecting  epoch based on EEG : ['Fz', 'C3', 'O1', 'F4']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O1', 'T8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz']
#     Rejecting  epoch based on EEG : ['T7', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['C3', 'Pz', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'O1', 'Oz', 'O2', 'P8', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['C3', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'Cz', 'T8']
#     Rejecting  epoch based on EEG : ['T7', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'T7', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'C3', 'T7', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'T8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['C3', 'O2', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'T7', 'Pz', 'Cz', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['C3']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1']
#     Rejecting  epoch based on EEG : ['F7', 'O2', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Pz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'O2', 'T8', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'T7', 'P7', 'T8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['Pz', 'O2']
#     Rejecting  epoch based on EEG : ['P8', 'T8']
#     Rejecting  epoch based on EEG : ['FC1', 'C3', 'CP1', 'O2', 'P8', 'Cz', 'T8']
#     Rejecting  epoch based on EEG : ['T8', 'FC2']
#     Rejecting  epoch based on EEG : ['T8', 'FC6']
#     Rejecting  epoch based on EEG : ['Oz', 'O2', 'FC6']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'T8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'T8', 'FC2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['FC1', 'C3']
#     Rejecting  epoch based on EEG : ['O2', 'T8']
#     Rejecting  epoch based on EEG : ['T8', 'F4']
#     Rejecting  epoch based on EEG : ['P8', 'T8']
#     Rejecting  epoch based on EEG : ['O2', 'T8']
#     Rejecting  epoch based on EEG : ['Pz', 'Oz', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'T7', 'CP1', 'P8', 'Cz', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'Pz', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'Oz', 'O2', 'P4', 'P8']
#     Rejecting  epoch based on EEG : ['FC1', 'Pz', 'O2', 'P4', 'P8', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'Oz', 'O2', 'P4', 'P8', 'Cz', 'T8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'CP1', 'Pz', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'P7', 'O1', 'O2', 'P4', 'P8', 'CP6', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'CP1', 'Pz', 'P3', 'O2', 'P8', 'CP2', 'Cz', 'FC6', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'O1', 'Oz', 'O2', 'P8', 'T8', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'Pz', 'P3', 'P7', 'O1', 'O2', 'P8', 'CP2', 'Cz', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FC1', 'T7', 'CP5', 'O1', 'O2', 'P8', 'CP6', 'Cz', 'T8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'C3', 'T7', 'T8', 'FC6']
#     Rejecting  epoch based on EEG : ['T7', 'T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'C3', 'T7', 'T8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'T7', 'P8', 'T8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['T7', 'P8']
#     Rejecting  epoch based on EEG : ['FC1', 'T7', 'CP1', 'Pz', 'P8', 'CP2', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'P8', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FC1', 'C3', 'P8', 'Cz', 'F4']
#     Rejecting  epoch based on EEG : ['T7', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'P3', 'O1']
#     Rejecting  epoch based on EEG : ['Fz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'T8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Pz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'CP1', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'CP2', 'Cz']
#     Rejecting  epoch based on EEG : ['O1', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'FC2']
#     Rejecting  epoch based on EEG : ['FC1', 'CP1', 'Pz', 'O2', 'P4', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['P3']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'Cz', 'C4', 'FC6', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['FC1', 'C3', 'CP1', 'Pz', 'P3', 'CP2', 'Cz', 'C4', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'Oz', 'O2', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['FC1', 'P8']
#     Rejecting  epoch based on EEG : ['Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FC5', 'FC1', 'T7', 'Pz', 'P3', 'O2', 'P8', 'Cz', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'T8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['Cz', 'T8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'T8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'T8', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['P3', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['T8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'T7', 'O1', 'O2', 'P8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FC1', 'T7']
#     Rejecting  epoch based on EEG : ['O2', 'P8']
#     Rejecting  epoch based on EEG : ['O2', 'Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Pz', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'P8']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'T7', 'O1', 'Oz', 'O2', 'P8', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['P8', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'T7', 'O1', 'Oz', 'O2', 'P8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'CP6', 'Cz']
#     Rejecting  epoch based on EEG : ['FC1', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Cz']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'Oz', 'O2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'FC2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['F3', 'FC1', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'Pz', 'O1', 'Oz', 'O2', 'P4', 'CP2', 'Cz', 'C4', 'T8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['O2', 'F4']
#     Rejecting  epoch based on EEG : ['O2', 'Cz']
# ...
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'Cz', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'P7', 'F4']
#     Rejecting  epoch based on EEG : ['Fz']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'O1', 'Oz', 'O2', 'P8', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'P7', 'CP6', 'C4', 'FT10', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'T7', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['C3', 'T7', 'CP5', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'P4', 'P8', 'CP6', 'CP2', 'C4', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC1', 'C3', 'T7', 'CP1', 'P7']
#     Rejecting  epoch based on EEG : ['FT9']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'CP1', 'P3', 'P7', 'O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'Pz', 'O1', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'C4', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'P4', 'P8', 'CP2', 'Cz', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'Pz', 'P3', 'P7', 'O2', 'P8', 'Cz', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'T7', 'Pz', 'P7', 'O1', 'Oz', 'O2', 'P8', 'CP6', 'Cz', 'C4', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'T7', 'CP5', 'CP1', 'Pz', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC1', 'C3', 'T7', 'CP5', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['FT9', 'FC1', 'C3', 'T7', 'CP1', 'P7', 'O1', 'Oz', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'C3', 'CP1', 'O1', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'C4', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'Cz', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FC1', 'O2', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['FT9', 'T7', 'CP5', 'Pz', 'P7', 'O1', 'Oz', 'O2', 'P8', 'CP6', 'Cz', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC1', 'T7', 'P7', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'CP1', 'Pz', 'P8', 'CP2', 'Cz', 'C4', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['T7', 'O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'C4', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'T7', 'CP5', 'P3', 'P7', 'O1', 'Oz', 'P8', 'CP6', 'Cz', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC1', 'T7', 'CP5', 'CP1', 'Pz', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'O2', 'P4', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'Cz', 'C4', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'P7', 'O1', 'Oz', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC1', 'T7', 'P7', 'C4']
#     Rejecting  epoch based on EEG : ['Fz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'CP1', 'Pz', 'P3', 'O1', 'O2', 'P4', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'T7', 'CP5', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8', 'CP6', 'Cz', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'P7', 'O1', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'T7', 'CP5', 'P7', 'O1', 'O2', 'P4', 'P8', 'Cz', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'O2', 'P8', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'P7', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'CP2', 'Cz', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC1', 'C3', 'T7', 'CP1', 'P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'T7', 'CP5', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'Pz', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'Oz', 'O2', 'Cz', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'Cz', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'Cz', 'C4', 'FT10', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC1']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'C4', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC1', 'T7', 'P7', 'P8', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'C3', 'T7', 'CP5', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC1', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'Cz', 'C4', 'FT10', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8', 'TP10', 'CP2', 'Cz', 'C4', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'FT10']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Fz']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'T7', 'P7', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC1', 'T7', 'P7', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2', 'C4', 'FT10']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'C3', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8', 'CP2', 'Cz', 'FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC1', 'C3', 'T7', 'P7', 'P8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P7', 'O1', 'P8', 'CP6', 'Cz', 'FT10', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz']
#     Rejecting  epoch based on EEG : ['FC1', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'T7', 'CP5', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'FT9', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'P4', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P7', 'O1', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10']
#     Rejecting  epoch based on EEG : ['FT9', 'T7', 'P7', 'CP6', 'C4', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['Fz', 'FC1', 'T7', 'P7', 'Cz']
# 597 bad epochs dropped

# %% [markdown]
# # Evokeds

# %% [markdown]
# ## parameters

# %%
# directory
input_dir = work_dir + 'data_preprocessed/4_epochs/'
output_dir = work_dir + 'data_preprocessed/5_evokeds/'
# create a folder if the folder doesn't exist
os.makedirs(output_dir, exist_ok=True)

# condition list
cond_list = [
    'ChEn-devi', 
    'ChEn-stan', 
    'EnCh-devi', 
    'EnCh-stan', 
    'EnIn-devi', 
    'EnIn-stan', 
    'InEn-devi', 
    'InEn-stan'
]

exclude_ppts = [
    '114' # too noisy
]

erp_baseline = (-0.1, 0)

# %%
#### get ERP ####

# get file names
all_input = os.listdir(input_dir)
all_output = os.listdir(output_dir)

# for each file
for file in all_input:
    
    if file.endswith("_epo.fif") and (file.split('_')[1]+'_ave.fif' not in all_output):
        
        # extract subject number
        ppt = file.split('_')[1]

        if ppt in exclude_ppts:
            continue

        # read in data
        epochs = mne.read_epochs(input_dir + file, preload = True)

        # get erp for each condition
        evoked_list = []
        for cond in cond_list:
            
            # average | get ERP for each condition
            evoked = epochs[cond].average(by_event_type=False)

            # add condition label
            evoked.comment = cond

            # apply baseline
            evoked.apply_baseline(baseline=erp_baseline)

            # append
            evoked_list.append(evoked)
        
        # save
        mne.write_evokeds(output_dir + ppt + '_ave.fif', evoked_list)
    
        # reduce memory usage
        del epochs, evoked, evoked_list
# Out:
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_185_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 435 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_133_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1510 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_125_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 680 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_219_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 780 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)

# %% [markdown]
# # ERSP
# segmenting continuous EEG into epochs for ERSP analysis
# - re-reference
# - segmentation

# %% [markdown]
# ## parameters

# %%
# directory
input_dir = work_dir + 'data_preprocessed/3_ica/'
output_dir = work_dir + 'data_preprocessed/4_tfr_evokeds_unnormalized/'
# create a folder if the folder doesn't exist
os.makedirs(output_dir, exist_ok=True)


# Epoch window: 
epoch_t_start = -1; epoch_t_end = 2

# criteria to reject epoch
reject_criteria = dict(eeg = 100e-6)       # 100 µV
# reject_criteria = dict(eeg = 150e-6)       # 150 µV
# reject_criteria = dict(eeg = 200e-6)       # 200 µV

exclude_ppts = [
    '114' # too noisy
]

# tfr method
tfr_method = 'morlet'

# baseline
tfr_baseline = (-0.45, -0.3)

# frequencies
freq_start = 3
freq_end = 30
n_freq = 28
freqs = np.linspace(start=freq_start, stop=freq_end, num=n_freq)

# cycles
cycl_start = 3
cycl_step = 0.8
n_cycl = n_freq
n_cycles = np.linspace(start=cycl_start, stop=cycl_start+cycl_step*(n_cycl-1), num=n_cycl)

condition_list = ['ChEn-stan', 'ChEn-devi', 'EnCh-stan', 'EnCh-devi']

# %%
# initialize a list for subjects with too many bad trials
# get file names
all_input = os.listdir(input_dir)
all_output = os.listdir(output_dir)


#### re-reference, and epoch ####
for file in all_input:
    
    if file.endswith("ica.fif") and (file.split('_')[1] + '_tfr.hdf5' not in all_output):

        # skip bad participants
        if file.split('_')[1] in exclude_ppts:
            continue
        
        # read in data
        raw = mne.io.read_raw_fif(input_dir + file, preload = True)
        
        # average-mastoids re-reference
        raw.set_eeg_reference(ref_channels = ['TP9', 'TP10'])
        
        # get event info for segmentation
        events_from_annot, event_dict = mne.events_from_annotations(raw, verbose='WARNING')
        
        # segmentation for ERP
        epochs = mne.Epochs(
            raw,
            events = events_from_annot, event_id = event_dict,
            tmin = epoch_t_start, tmax = epoch_t_end,
            # apply baseline correction
            baseline = None,
            # remove epochs that meet the rejection criteria
            reject = reject_criteria,
            preload = True,
        )
        


        # for each event, remove 0 trial events, record info, and check if a subject is bad
        for k, v in event_dict.items():

            # good trial count
            trial_count = len(epochs[k])

            # remove 0 trial event
            if trial_count==0:
                del epochs.event_id[k]

            # good trial rate
            goodTrial_rate = round( trial_count/sum(events_from_annot[:,2]==v), 2 )
            
            # record epoch summary
            with open(output_dir + 'epoch_summary.txt', 'a+') as f:
                _ =f.write(file.split('_')[1] + '\t' + k + '\t' + str(trial_count) + '\t' + str(goodTrial_rate) + '\n')


        # ERSP

        # initialize tfrs list
        tfrs = []
        
        for condition in condition_list:
            # compute ERSP
            power = epochs[condition].compute_tfr(
                method=tfr_method,
                freqs=freqs,
                n_cycles=n_cycles,
                # return_itc=True,
                decim=3,
            )

            # baseline correction
            power.apply_baseline(mode="ratio", baseline=tfr_baseline, verbose='WARNING')
            
            # average
            power = power.average(method = 'mean', dim = 'epochs')

            # add comment
            power.comment = condition

            # append
            tfrs.append(power)
            
        # save single subject file
        mne.time_frequency.write_tfrs(fname=output_dir + file.split('_')[1] + '_tfr.hdf5', 
                                      tfr=tfrs)

        # release memory
        del power, tfrs
# Out:
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_191_corr_prep_ica.fif...
#     Range : 4661 ... 845786 =     18.644 ...  3383.144 secs
# Ready.
# Reading 0 ... 841125  =      0.000 ...  3364.500 secs...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_2898/4155833368.py:17: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_191_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload = True)
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1648 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1648 events and 751 original time points ...
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'T7', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'T7', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['FC6', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'C3', 'T7', 'CP5', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'C3', 'T7', 'CP5', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'CP5', 'C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4']
#     Rejecting  epoch based on EEG : ['CP6', 'C4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['F7', 'P8', 'C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'P4', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'P4', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FT9', 'T7', 'CP5', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'CP6', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'CP6', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC6', 'F4']
#     Rejecting  epoch based on EEG : ['FC6', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'F4']
#     Rejecting  epoch based on EEG : ['F7', 'C4', 'F4']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC1', 'C3', 'T7', 'CP5', 'P3', 'P7', 'P4', 'P8', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'C3', 'T7', 'CP5', 'P4', 'P8', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'C3', 'T7', 'CP5', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FC6']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['F7', 'F4']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'T7', 'T8', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'T7', 'T8', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['T7']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['C4', 'FT10', 'FC6', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'FC2']
#     Rejecting  epoch based on EEG : ['F7', 'FC6']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6']
#     Rejecting  epoch based on EEG : ['CP6']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'C3', 'T7', 'CP5']
#     Rejecting  epoch based on EEG : ['F7', 'C3', 'T7', 'CP5', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['T7', 'CP6', 'FC2']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'CP5', 'CP6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'CP5', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['F7', 'FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'T7', 'P4', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'T7', 'P4', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'C3', 'T7', 'CP5', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'C3', 'T7', 'CP5', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'C3', 'T7', 'CP5', 'C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EEG : ['FC6']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'P4', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC1', 'C3', 'T7', 'CP5', 'P7', 'P4', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'P4', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'O2', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['F7', 'O1', 'O2', 'FC2']
#     Rejecting  epoch based on EEG : ['F7', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['Fz', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
# 117 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_258_corr_prep_ica.fif...
#     Range : 23135 ... 918784 =     92.540 ...  3675.136 secs
# Ready.
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_2898/4155833368.py:17: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_258_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload = True)
# Reading 0 ... 895649  =      0.000 ...  3582.596 secs...
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1714 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1714 events and 751 original time points ...
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['FC5', 'CP5', 'P8']
#     Rejecting  epoch based on EEG : ['FC5', 'CP5', 'P8']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['CP6']
#     Rejecting  epoch based on EEG : ['FC5', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['FC5', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'F8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['FC2', 'F4']
#     Rejecting  epoch based on EEG : ['FC2', 'F4']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P4', 'P8', 'CP6', 'C4', 'FT10', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'C4', 'FT10', 'FC6', 'F4']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'C3', 'CP5', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'C4', 'FT10', 'FC6']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8', 'FT10']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'FC5', 'T7', 'CP5', 'P7', 'P8', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'FC5', 'T7', 'CP5', 'P7', 'P8', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['FC5', 'CP5', 'P8', 'FT10']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['FT9', 'FC5', 'CP5', 'O1', 'P8', 'CP6', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'T7', 'CP5', 'P7', 'O1', 'P8', 'CP6', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'T7', 'CP5', 'P7', 'O1', 'P8', 'FT10', 'FC6', 'F8']
#     Rejecting  epoch based on EEG : ['P8', 'FT10']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'C3', 'T7', 'CP5', 'P8', 'CP6', 'C4', 'FT10', 'FC6', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['P8', 'CP6', 'FT10']
#     Rejecting  epoch based on EEG : ['P8', 'CP6', 'FT10']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'T7', 'FT10', 'FC6', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'T7', 'FT10', 'FC6', 'F8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10']
#     Rejecting  epoch based on EEG : ['FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['CP5', 'P8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'P8', 'F4']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['P8', 'FT10']
#     Rejecting  epoch based on EEG : ['C3', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8']
#     Rejecting  epoch based on EEG : ['C3', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'FC5', 'T7', 'CP5', 'P7', 'O1', 'P8', 'CP6', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'FC5', 'T7', 'CP5', 'P7', 'O1', 'P8', 'CP6', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'O1', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'FC5', 'T7', 'CP5', 'P7', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'FT10']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FC2', 'F4']
#     Rejecting  epoch based on EEG : ['FC2', 'F4']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'P8', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz', 'P8', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'O1', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F3']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'F4']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'T7', 'CP5', 'CP6', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7', 'CP5', 'P7', 'O1', 'P8']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'T7', 'CP5', 'P7', 'O1', 'P8']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'FC5', 'T7', 'CP5']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'FC5', 'T7', 'CP5']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['P8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['P8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FT9', 'T7', 'F4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['P7', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['P7', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'T7', 'CP5', 'P3', 'P8', 'CP6', 'FT10', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'T7', 'CP5', 'P3', 'P8', 'CP6', 'FT10', 'FC2', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC5', 'CP5', 'P8', 'CP6', 'FT10']
#     Rejecting  epoch based on EEG : ['FC5', 'CP5', 'P8', 'CP6', 'FT10']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['P7', 'F4']
#     Rejecting  epoch based on EEG : ['P7', 'F4']
#     Rejecting  epoch based on EEG : ['FC2', 'F4']
#     Rejecting  epoch based on EEG : ['FC2', 'F4']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'P7', 'P4', 'P8', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'P7', 'P4', 'P8', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'P4', 'P8', 'CP6', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'P7', 'P4', 'P8', 'CP6', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC5', 'FC1', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'O1', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10']
#     Rejecting  epoch based on EEG : ['FC5', 'FC1', 'CP5', 'Pz', 'P8', 'CP6', 'CP2', 'Cz', 'FT10']
#     Rejecting  epoch based on EEG : ['FC5', 'CP5', 'P8', 'CP6', 'FT10']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['F3', 'FC1']
#     Rejecting  epoch based on EEG : ['F3', 'FC1']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'C3', 'T7', 'CP5', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'C4', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Pz', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'C4']
#     Rejecting  epoch based on EEG : ['Pz', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP2', 'Cz', 'C4']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT9', 'FC5', 'T7', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC2']
#     Rejecting  epoch based on EEG : ['C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'C3', 'T7', 'CP5']
#     Rejecting  epoch based on EEG : ['FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC2']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC5', 'P7', 'O1', 'O2', 'P8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FC5', 'P7', 'O1', 'O2', 'P8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['P8']
# 217 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_216_corr_prep_ica.fif...
#     Range : 2382 ... 853394 =      9.528 ...  3413.576 secs
# Ready.
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_2898/4155833368.py:17: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_216_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload = True)
# Reading 0 ... 851012  =      0.000 ...  3404.048 secs...
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1683 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1683 events and 751 original time points ...
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'CP5', 'F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'CP5', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'FC1', 'C3', 'F8']
#     Rejecting  epoch based on EEG : ['C3']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'O2', 'P8', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'O2', 'P8', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FT9', 'C3', 'CP6', 'T8', 'FC6']
#     Rejecting  epoch based on EEG : ['FT9', 'C3', 'CP6', 'FC6']
#     Rejecting  epoch based on EEG : ['FT9', 'C3']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'C3', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['CP6']
#     Rejecting  epoch based on EEG : ['FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'O1', 'Oz', 'O2', 'F8']
#     Rejecting  epoch based on EEG : ['C3']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'O1', 'Oz', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FT9', 'FC5', 'FC1', 'C3', 'O1', 'Oz', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['F4', 'F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'FC1', 'C3', 'CP5', 'O2', 'CP6']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'FC1', 'C3', 'CP5', 'CP6']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
# 50 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_270_corr_prep_ica.fif...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_2898/4155833368.py:17: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_270_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload = True)
#     Range : 3456 ... 1002543 =     13.824 ...  4010.172 secs
# Ready.
# Reading 0 ... 999087  =      0.000 ...  3996.348 secs...
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1647 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1647 events and 751 original time points ...
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['FT10']
#     Rejecting  epoch based on EEG : ['FT9', 'Pz', 'O1', 'Oz', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'Pz', 'O1', 'Oz', 'O2', 'Cz', 'C4', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'Pz', 'O1', 'Oz', 'P4', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'Pz', 'O1', 'Oz', 'P4', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'C3', 'T7', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'O1', 'Oz', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'O1', 'Oz', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'T7', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT9', 'Pz', 'O1', 'Oz', 'O2', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['F3', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'FT10']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8', 'Cz', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC5', 'FC1', 'Pz', 'O1', 'Oz', 'P8', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'Pz', 'O1', 'Oz', 'P8', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['F3', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'C3', 'T7', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT10']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['FT10']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'TP10', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'TP10', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'P4', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'FC6']
#     Rejecting  epoch based on EEG : ['FT10']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'C3', 'CP1', 'Pz', 'P3', 'O1', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'T8', 'FT10', 'FC6', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'CP1', 'Pz', 'O1', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'T8', 'FT10', 'FC6', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'O1', 'Oz', 'O2', 'CP6', 'CP2', 'Cz', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC2', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC2', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['FT10']
#     Rejecting  epoch based on EEG : ['FT9', 'T7']
#     Rejecting  epoch based on EEG : ['FT9', 'T7']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FT9', 'Pz', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P8', 'CP6', 'CP2', 'Cz', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'FC5', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'O1', 'O2', 'P8', 'CP2', 'C4', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'Pz', 'P7', 'O1', 'Oz', 'O2', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'Pz', 'O1', 'Oz', 'P4', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Pz', 'C4', 'T8', 'FC6', 'FC2']
#     Rejecting  epoch based on EEG : ['FT9', 'T7']
#     Rejecting  epoch based on EEG : ['FT9', 'T7', 'O1']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'T8', 'FT10', 'FC6', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P7', 'O1', 'Oz', 'O2', 'P8', 'T8', 'FT10', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'T7', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'T7', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P7', 'FT10']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P7', 'FT10']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['FT10']
#     Rejecting  epoch based on EEG : ['FT10']
#     Rejecting  epoch based on EEG : ['FT9', 'Pz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FT9', 'Pz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'C3', 'T7', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT9']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT10', 'F8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'FC1', 'C3', 'O1', 'Oz', 'O2', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'Cz', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'Cz', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'O1', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'FT9', 'FC5', 'O1', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['FT9', 'T7', 'O2', 'FT10']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'Pz', 'O1', 'P4', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'Pz', 'O1', 'P4', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['F3', 'C4', 'T8', 'FT10', 'FC6', 'FC2']
#     Rejecting  epoch based on EEG : ['F3', 'C4', 'T8', 'FT10', 'FC6', 'FC2']
#     Rejecting  epoch based on EEG : ['C4', 'FC6']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'Pz', 'O1', 'Oz', 'P4', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP1', 'Pz', 'O1', 'P4', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'C3', 'T7', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'T7', 'C4', 'T8', 'FT10', 'FC6', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['FT10']
#     Rejecting  epoch based on EEG : ['FT10']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'TP10', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'TP10', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'Pz', 'O1', 'Oz', 'P4', 'CP2', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['Pz', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['FT9', 'T7']
#     Rejecting  epoch based on EEG : ['FT9', 'T7']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['FT9']
# ...
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FC1', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['CP5', 'CP6', 'C4', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'CP6', 'C4', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['P8', 'CP6']
#     Rejecting  epoch based on EEG : ['P8', 'CP6']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O2', 'P8', 'CP6', 'F4']
#     Rejecting  epoch based on EEG : ['P8', 'CP6', 'C4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['F3', 'C4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'CP5', 'C4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'C4']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'O1', 'Cz']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'FC1', 'O1', 'Cz']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'CP5']
#     Rejecting  epoch based on EEG : ['F3', 'CP5']
#     Rejecting  epoch based on EEG : ['C3', 'CP5', 'CP1', 'Pz', 'P3', 'P8', 'CP6', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC1', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'P4', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC1', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'P4', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'CP5', 'F4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['C3', 'CP5']
#     Rejecting  epoch based on EEG : ['C3', 'CP5', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'F4']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F3', 'O1', 'Oz', 'O2', 'F4']
#     Rejecting  epoch based on EEG : ['F3', 'O1', 'Oz', 'O2', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F4']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['F3', 'CP5']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['P7', 'O1']
#     Rejecting  epoch based on EEG : ['CP5', 'P7', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'O2']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['Oz', 'O2']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5', 'Pz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Pz', 'O2', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'F8']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['F3', 'CP5', 'CP6', 'C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'C4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'F8']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['CP5', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['CP5', 'Oz', 'O2', 'F4']
#     Rejecting  epoch based on EEG : ['O1', 'O2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC1', 'C3', 'CP5', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC1', 'C3', 'CP5', 'CP6', 'CP2', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5', 'C4', 'F4']
#     Rejecting  epoch based on EEG : ['CP5', 'C4', 'F4']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['C4', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'C4', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'CP5', 'CP1', 'Pz', 'P3', 'O1', 'Oz', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'T8', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'CP5', 'CP6', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['FT10', 'FC6', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5', 'C4', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['F3', 'FT10', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['CP5', 'C4']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'CP5', 'CP6', 'CP2', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['C3', 'CP5']
#     Rejecting  epoch based on EEG : ['C3', 'CP5', 'CP6', 'C4', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'F4']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['P7', 'O1', 'Oz']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['F4', 'F8']
#     Rejecting  epoch based on EEG : ['F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'CP6', 'C4', 'FT10', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'CP6', 'C4', 'FT10', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['CP5', 'O1', 'C4']
#     Rejecting  epoch based on EEG : ['CP5', 'C4']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5', 'C4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'C4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'C4', 'FT10', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'C4', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'CP6', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'CP6', 'C4', 'FC6', 'FC2', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'C4']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['O1', 'F4']
#     Rejecting  epoch based on EEG : ['CP5', 'O1', 'CP6', 'C4', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'P7', 'O1', 'CP6', 'C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['CP5', 'P7', 'O1', 'CP6', 'C4', 'FC6', 'F4', 'F8']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['O1']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['CP5', 'O1', 'Oz', 'O2']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5', 'C4']
#     Rejecting  epoch based on EEG : ['CP5', 'C4']
# 184 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# Opening raw data file /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_163_corr_prep_ica.fif...
# /var/folders/j8/8nyf6njj5nzfjcv6s23y3nn40000gn/T/ipykernel_2898/4155833368.py:17: RuntimeWarning: This filename (/Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/3_ica/Yas_163_corr_prep_ica.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(input_dir + file, preload = True)
#     Range : 1802 ... 933967 =      7.208 ...  3735.868 secs
# Ready.
# Reading 0 ... 932165  =      0.000 ...  3728.660 secs...
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 1667 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1667 events and 751 original time points ...
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['FC2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['CP6']
#     Rejecting  epoch based on EEG : ['FC5', 'C3', 'CP5', 'CP6', 'C4', 'FT10', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['C3', 'C4']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['Fz', 'F7', 'FT9', 'P4', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'P4', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'P4', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['C4', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['P7', 'P8']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'P4', 'CP2', 'Cz', 'C4', 'FC2']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'P4', 'CP2', 'Cz', 'C4', 'FC2']
#     Rejecting  epoch based on EEG : ['C4']
#     Rejecting  epoch based on EEG : ['F7', 'FT9', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'P4', 'P8', 'CP6', 'CP2', 'Cz', 'C4', 'FC2']
#     Rejecting  epoch based on EEG : ['C4', 'FC2']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'P4', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'P4', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'P4', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'CP2', 'Cz', 'C4', 'FC2']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'CP2', 'Cz', 'C4', 'FC2']
#     Rejecting  epoch based on EEG : ['CP6', 'C4']
#     Rejecting  epoch based on EEG : ['Fz', 'F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'Oz', 'O2', 'P4', 'P8', 'TP10', 'CP6', 'CP2', 'Cz', 'C4', 'FT10', 'FC6', 'FC2', 'F4', 'F8', 'TP9']
#     Rejecting  epoch based on EEG : ['CP6', 'C4']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'CP2', 'Cz', 'C4', 'FT10', 'FC2']
#     Rejecting  epoch based on EEG : ['F3', 'F7', 'FT9', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'Pz', 'P3', 'P7', 'O1', 'CP2', 'Cz', 'C4', 'FT10', 'FC2']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['P7']
#     Rejecting  epoch based on EEG : ['C4', 'FC2']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FT10', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['P8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FC2', 'F8']
#     Rejecting  epoch based on EEG : ['CP6', 'C4', 'FC2']
#     Rejecting  epoch based on EEG : ['C4']
# 45 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.5s

# %% [markdown]
# # Extract GAM data

# %% [markdown]
# ## parameters

# %%
# directory
input_dir = work_dir + 'data_preprocessed/4_epochs/'
output_dir = work_dir + 'data_analysis/gam/'
# create a folder if the folder doesn't exist
# os.makedirs(output_dir, exist_ok=True)

epoch_baseline = (-0.1, 0)


#### get ERP ####

# get file names
all_input = os.listdir(input_dir)
all_output = os.listdir(output_dir)


# for each file
#### re-reference, and epoch ####
for file in all_input:
    
    if file.endswith("ica.fif") and (file.split('_')[1]+'_gam.csv' not in all_output):
        
        # read in data
        raw = mne.io.read_raw_fif(input_dir + file, preload = True)
        
        # average-mastoids re-reference
        raw.set_eeg_reference(ref_channels = ['TP9', 'TP10'])
        
        #### this is for source calculation ####
        # filter the data, optional
        # raw = raw.filter(l_freq=None, h_freq=30) 

        # sphere = mne.make_sphere_model('auto', 'auto', raw.info)
        # src = mne.setup_volume_source_space(sphere=sphere, exclude=30., pos=15.)
        # forward = mne.make_forward_solution(raw.info, trans=None, src=src, bem=sphere)
        # raw = raw.set_eeg_reference('REST', forward=forward)
        ########################################
        
        # get event info for segmentation
        events_from_annot, event_dict = mne.events_from_annotations(raw, verbose='WARNING')
        
        # segmentation for ERP
        epochs = mne.Epochs(
            raw,
            events = events_from_annot, event_id = event_dict,
            tmin = erp_t_start, tmax = erp_t_end,
            # apply baseline correction
            baseline = None,
            # remove epochs that meet the rejection criteria
            reject = reject_criteria,
            preload = True,
        )

        # remove 0 trial events, record info, and check if a subject is bad
        for k, v in event_dict.items():

            # good trial count
            trial_count = len(epochs[k])

            # remove 0 trial event
            if trial_count==0:
                del epochs.event_id[k]

            # good trial rate
            goodTrial_rate = round( trial_count/sum(events_from_annot[:,2]==v), 2 )
            
            # record epoch summary
            with open(output_dir + 'epoch_summary.txt', 'a+') as f:
                _ =f.write(file.split('_')[1] + '\t' + k + '\t' + str(trial_count) + '\t' + str(goodTrial_rate) + '\n')

        # save single participant file
        epochs.save(output_dir + file.split('.')[0] + '_epo.fif',
                   overwrite=True)


for file in all_input:
    
    if file.endswith("_epo.fif") and (file.split('_')[1]+'_gam.csv' not in all_output):
        
        # extract subject number
        ppt = file.split('_')[1]

        # read in data
        epochs = mne.read_epochs(input_dir + file, preload = True)
        
        # apply baseline
        epochs.apply_baseline(baseline=epoch_baseline, verbose='WARNING')

        # extract data
        df = epochs.to_data_frame(time_format='ms')

        # add info of group, ppt, and item
        df['participant'] = ppt

        # # initialize panda dataframe
        # df = pd.DataFrame()

        # # get erp for each item
        # for item in epochs.event_id.keys():
                        
        #     # average | get ERP for each condition
        #     evoked = epochs[item].average()

        #     # append
        #     tmp_df = evoked.to_data_frame(time_format='ms')
            
        #     # add info of group, ppt, and item
        #     tmp_df['participant'] = ppt

        #     # row bind data
        #     df = pd.concat([df, tmp_df])
            
        # save
        df.to_csv(output_dir + ppt + '_gam.csv', index=False)
        
        # reduce memory usage
        del df
# Out:
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_246_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1628 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_208_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1650 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_220_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1664 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_139_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1692 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_177_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1712 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_125_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1622 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_214_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1719 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_143_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1592 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_243_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1606 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_114_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1697 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_225_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1474 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_172_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1622 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_239_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1653 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_120_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1722 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_196_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1652 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_211_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1704 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_108_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1606 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_146_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1681 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_209_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1664 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_247_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1413 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_110_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1724 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_221_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1707 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_176_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1685 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_138_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1634 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_124_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1617 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_215_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1590 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_192_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1632 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_242_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1654 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_224_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1651 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_173_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1681 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_238_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1594 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_121_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1620 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_210_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1587 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_147_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1624 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_109_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1590 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_113_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1572 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_244_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1624 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_175_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1704 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_222_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1705 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_169_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1657 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_127_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1653 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_270_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1563 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_216_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1662 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_258_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1612 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_191_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1589 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_158_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1598 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_116_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1549 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_241_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1688 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_188_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1660 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_170_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1719 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_227_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1554 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_269_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1646 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_194_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1631 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_144_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1758 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_213_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1616 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_112_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1598 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_245_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1564 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_174_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1619 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_223_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1571 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_126_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1657 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_168_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1502 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_217_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1694 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_117_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1669 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_240_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1667 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_189_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1660 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_171_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1611 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_226_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1710 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_123_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1682 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_274_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1600 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_195_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1585 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_145_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1582 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_212_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1660 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_178_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1621 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_136_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1592 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_207_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1656 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_249_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1662 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_150_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1664 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_255_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1695 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_102_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1627 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_233_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1659 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_164_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1685 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_264_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1662 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_133_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1618 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_185_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1662 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_202_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1607 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_155_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1692 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_250_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1673 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_149_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1672 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_107_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1676 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_199_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1676 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_236_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1626 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_161_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1618 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_260_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1649 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_137_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1662 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_248_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1713 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_206_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1635 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_151_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1389 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_181_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1640 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_254_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1580 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_103_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1699 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_232_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1675 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_165_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1677 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_265_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1474 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_132_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1613 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_184_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1616 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_203_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1650 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_251_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1609 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_106_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1611 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_148_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1726 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_198_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1561 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_237_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1663 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_134_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1655 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_263_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1699 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_152_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1674 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_205_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1593 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_100_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1604 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_257_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1588 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_219_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1600 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_128_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1641 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_166_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1647 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_231_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1645 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_131_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1567 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_228_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1695 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_119_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1588 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_157_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1553 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_105_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1665 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_252_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1612 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_163_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1644 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_234_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1595 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_262_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1642 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_153_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1381 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_204_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1589 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_183_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1418 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_101_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1500 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_218_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1662 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_256_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1697 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_167_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1693 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_230_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1662 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_130_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1640 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_229_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1684 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_267_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1599 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_186_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1630 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_156_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1602 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_118_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1556 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_201_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1630 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_104_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1695 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_253_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1627 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_162_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1635 matching events found
# No baseline correction applied
# 0 projection items activated
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/4_epochs/Yas_235_corr_prep_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     900.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1525 matching events found
# No baseline correction applied
# 0 projection items activated

# %% [markdown]
# # Extract ERP data

# %% [markdown]
# ## parameters

# %%
# directory
input_dir = work_dir + 'data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/'
output_dir = work_dir + 'data_analysis/erp/'
# create a folder if the folder doesn't exist
os.makedirs(output_dir, exist_ok=True)

# condition list
cond_list = [
    'ChEn-devi', 
    'ChEn-stan', 
    'EnCh-devi', 
    'EnCh-stan', 
    'EnIn-devi', 
    'EnIn-stan', 
    'InEn-devi', 
    'InEn-stan'
]

erp_baseline = (-0.1, 0)

# %%
#### get ERP ####

# get file names
all_input = os.listdir(input_dir)
all_output = os.listdir(output_dir)


# for each file
for file in all_input:
    
    if file.endswith("_epo.fif") and (file.split('_')[1]+'_erp.csv' not in all_output):

        # initialize panda dataframe
        df = pd.DataFrame()
        
        # extract subject number
        ppt = file.split('_')[1]

        # read in data
        epochs = mne.read_epochs(input_dir + file, preload = True)

        # get erp for each item
        for cond in cond_list:
                        
            # average | get ERP for each condition
            evoked = epochs[cond].average(by_event_type=False)

            # apply baseline
            evoked.apply_baseline(baseline=erp_baseline)

            # append
            tmp_df = evoked.to_data_frame(time_format='ms')
            
            # add info of group, ppt, and item
            tmp_df['participant'] = ppt
            tmp_df['condition'] = cond

            # row bind data
            df = pd.concat([df, tmp_df])
        # save
        df.to_csv(output_dir + ppt + '_erp.csv', index=False)
# Out:
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_152_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1675 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_200_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1427 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_216_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1679 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_144_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1771 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_168_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1653 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_106_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1664 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_254_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1604 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_242_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1675 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_110_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1733 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_122_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1518 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_270_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1587 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_194_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1637 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_208_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1691 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_134_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1708 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_118_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1645 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_176_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1701 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_224_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1680 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_232_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1712 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_256_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1711 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_238_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1642 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_104_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1705 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_112_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1608 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_240_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1701 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_188_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1691 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_202_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1639 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_150_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1682 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_146_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1724 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_128_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1685 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_214_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1752 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_226_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1716 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_248_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1721 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_174_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1645 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_162_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1646 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_230_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1690 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_196_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1666 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_120_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1724 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_136_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1646 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_158_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1654 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_264_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1668 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_126_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1686 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_148_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1729 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_130_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1645 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_262_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1662 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_186_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1648 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_220_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1688 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_172_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1653 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_164_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1688 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_236_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1639 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_258_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1703 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_204_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1648 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_156_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1674 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_138_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1684 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_198_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1627 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_212_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1671 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_250_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1681 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_102_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1633 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_114_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1722 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_246_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1638 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_228_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1710 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_170_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1719 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_222_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1708 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_234_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1632 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_108_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1658 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_166_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1674 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# ...
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_237_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1694 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_221_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1718 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_173_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1681 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_245_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1624 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_117_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1692 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_101_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1655 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_253_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1659 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_211_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1712 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_143_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1666 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_155_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1710 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_207_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1657 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_269_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1657 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_235_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1667 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_167_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1735 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_109_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1602 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_171_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1654 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_223_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1679 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_185_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1680 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_133_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1634 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_125_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1656 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Reading /Users/chaohan/Library/CloudStorage/OneDrive-UniversityofToronto/Projects/Yas accent/data_preprocessed/ica_on_continuous_200mV_cutoff/4_epochs/Yas_219_corr_prep_ica_epo.fif ...
#     Found the data of interest:
#         t =    -100.00 ...     700.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1666 matching events found
# No baseline correction applied
# 0 projection items activated
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
# Applying baseline correction (mode: mean)
